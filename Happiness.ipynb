# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os

# %%
happiness_df = pd.read_csv('C:\\Users\\liana\\OneDrive\\Desktop\\Final Project\\world-happiness-report.csv')
happiness_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
pwd
# Out:
# 'C:\\Users\\liana\\OneDrive\\Desktop\\Final Project'

# %%
happiness_df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
to_drop = ['Positive affect', 'Negative affect']
happiness_df.drop(to_drop, inplace = True, axis = 1)
happiness_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
new_columns = {'Country name':'COUNTRY', 'year':'YEAR', 'Life Ladder':'HAPPINESS SCORE', 'Log GDP per capita':'GDP/capita',
               'Social support':'SUPPORT', 'Healthy life expectancy at birth':'HEALTH', 'Freedom to make life choices':'FREEDOM',
               'Generosity':'GENEROSITY', 'Perceptions of corruption':'CORRUPTION'}
happiness = pd.DataFrame.rename(happiness_df, columns = new_columns, inplace = True)
happiness_df.head(150)
happiness_df
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
happiness_df.isnull().sum()
# Out:
# COUNTRY              0
# YEAR                 0
# HAPPINESS SCORE      0
# GDP/capita          36
# SUPPORT             13
# HEALTH              55
# FREEDOM             32
# GENEROSITY          89
# CORRUPTION         110
# dtype: int64

# %%
happiness_df.info()
happiness_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   COUNTRY          1949 non-null   object
#  1   YEAR             1949 non-null   int64
#  2   HAPPINESS SCORE  1949 non-null   float64
#  3   GDP/capita       1913 non-null   float64
#  4   SUPPORT          1936 non-null   float64
#  5   HEALTH           1894 non-null   float64
#  6   FREEDOM          1917 non-null   float64
#  7   GENEROSITY       1860 non-null   float64
#  8   CORRUPTION       1839 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 137.2+ KB
# (1949, 9)

# %%
# Removing the “NaN” data from the CORRUPTION field in the data set
happiness_df['CORRUPTION'] = happiness_df['CORRUPTION'].fillna(0)
happiness_df.head(1949)
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
# Removing the “NaN” data from the GENEROSITY field in the data set
happiness_df['GENEROSITY'] = happiness_df['GENEROSITY'].fillna(0)
happiness_df.head(1949)
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
# Removing the “NaN” data from the HEALTH field in the data set
happiness_df['HEALTH'] = happiness_df['HEALTH'].fillna(0)
happiness_df.head(1949)
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
# Removing the “NaN” data from the GDP/capita field in the data set
happiness_df['GDP/capita'] = happiness_df['GDP/capita'].fillna(0)
happiness_df.head(1949)
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
# Removing the “NaN” data from the FREEDOM field in the data set
happiness_df['FREEDOM'] = happiness_df['FREEDOM'].fillna(0)
happiness_df.head(1949)
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
# Removing the “NaN” data from the SUPPORT field in the data set
happiness_df['SUPPORT'] = happiness_df['SUPPORT'].fillna(0)
happiness_df.head(1949)
# Out:
#           COUNTRY  YEAR  HAPPINESS SCORE  GDP/capita  SUPPORT  HEALTH  \
# 0     Afghanistan  2008            3.724       7.370    0.451   50.80
# 1     Afghanistan  2009            4.402       7.540    0.552   51.20
# 2     Afghanistan  2010            4.758       7.647    0.539   51.60
# 3     Afghanistan  2011            3.832       7.620    0.521   51.92
# 4     Afghanistan  2012            3.783       7.705    0.521   52.24
# ...           ...   ...              ...         ...      ...     ...
# 1944     Zimbabwe  2016            3.735       7.984    0.768   54.40
# 1945     Zimbabwe  2017            3.638       8.016    0.754   55.00
# 1946     Zimbabwe  2018            3.616       8.049    0.775   55.60
# 1947     Zimbabwe  2019            2.694       7.950    0.759   56.20
# 1948     Zimbabwe  2020            3.160       7.829    0.717   56.80
#
#       FREEDOM  GENEROSITY  CORRUPTION
# 0       0.718       0.168       0.882
# 1       0.679       0.190       0.850
# ...

# %%
corr_df = happiness_df.corr(method = 'pearson')
corr_df
# Out:
#                      YEAR  HAPPINESS SCORE  GDP/capita   SUPPORT    HEALTH  \
# YEAR             1.000000         0.035515   -0.023478  0.008824  0.067277
# HAPPINESS SCORE  0.035515         1.000000    0.562188  0.593421  0.417475
# GDP/capita      -0.023478         0.562188    1.000000  0.401393  0.549510
# SUPPORT          0.008824         0.593421    0.401393  1.000000  0.286026
# HEALTH           0.067277         0.417475    0.549510  0.286026  1.000000
# FREEDOM          0.204938         0.439112    0.221697  0.366674  0.197247
# GENEROSITY      -0.041417         0.186125   -0.000549  0.056570 -0.033150
# CORRUPTION      -0.078845        -0.334049   -0.188728 -0.102164 -0.147061
#
#                   FREEDOM  GENEROSITY  CORRUPTION
# YEAR             0.204938   -0.041417   -0.078845
# HAPPINESS SCORE  0.439112    0.186125   -0.334049
# GDP/capita       0.221697   -0.000549   -0.188728
# SUPPORT          0.366674    0.056570   -0.102164
# ...

# %%
corr_df.plot(kind='scatter', x='HAPPINESS SCORE', y='GDP/capita', title='Happiness Score vs GDP per Capita');

# %%
statistics = happiness_df.describe()
statistics
# Out:
#               YEAR  HAPPINESS SCORE   GDP/capita      SUPPORT       HEALTH  \
# count  1949.000000      1949.000000  1949.000000  1949.000000  1949.000000
# mean   2013.216008         5.466705     9.195408     0.807132    61.571398
# std       4.166828         1.115711     1.702742     0.135355    12.843519
# min    2005.000000         2.375000     0.000000     0.000000     0.000000
# 25%    2010.000000         4.640000     8.397000     0.747000    57.500000
# 50%    2013.000000         5.386000     9.443000     0.834000    65.000000
# 75%    2017.000000         6.283000    10.335000     0.905000    68.400000
# max    2020.000000         8.019000    11.648000     0.987000    77.100000
#
#            FREEDOM   GENEROSITY   CORRUPTION
# count  1949.000000  1949.000000  1949.000000
# mean      0.730366     0.000099     0.704958
# std       0.169611     0.158466     0.250322
# min       0.000000    -0.335000     0.000000
# 25%       0.642000    -0.106000     0.654000
# ...

# %%
happiness_df['HAPPINESS SCORE'].plot(kind='hist', x='HAPPINESS SCORE', legend= True, color= 'g', title='Happiness Score Distribution');

# %%
happiness_df['CORRUPTION'].plot(kind='hist', x='CORRUPTION', legend= True, color= 'r', title = 'Corruption Distribution')
# Out:
# <AxesSubplot:title={'center':'Corruption Distribution'}, ylabel='Frequency'>

# %%
csv_happiness = happiness_df.to_csv('happiness.csv')
